# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonaksojan2008/My_first_project/blob/main/Task_02_Student_profile_manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Task 2 - Student Profile Manager
name = input("Name: ")
age = int(input("Age: "))
department = input("Department: ")
cgpa = float(input("CGPA: "))
blood_group = input("Blood_Group: ")
email = input("Email: ")
phone = input("Phone: ")

print("\n" + "=" * 40)
print("        STUDENT PROFILE")
print("=" * 40)
print(f"Name          :{name}")
print(f"Age           :{age}")
print(f"Department    :{department}")
print(f"CGPA          :{cgpa}")
print(f"Blood_Group   :{blood_group}")
print(f"Email         :{email}")
print(f"Phone         :{phone}")
print("=" * 40)
# Out:
# Name: SONA K SOJAN
# Age: 18
# Department: BCA
# CGPA: 8.5
# Blood_Group: B+VE
# Email: sojanspna678@gmail.com
# Phone: 7907618302
#
# ...
#         STUDENT PROFILE
# ...
# Name          :SONA K SOJAN
# Age           :18
# Department    :BCA
# CGPA          :8.5
# Blood_Group   :B+VE
# Email         :sojanspna678@gmail.com
# Phone         :7907618302
# ...
