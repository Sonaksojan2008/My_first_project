# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonaksojan2008/My_first_project/blob/main/Task_04_YourTaskName.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name:   ")
course = input("Enter your course:   ")
collage = input("Enter your collage:   ")
skills = input("Enter your skills:   ")
projects = input("Enter your projects:   ")
linkedin =  input("Enter your linkedin:   ")
github = input("Enter your github:    ")

readme = f"""
#{name}

##About me
I am {name},a {course},student at {collage}

##Skills
{skills}

##Projects
{projects}

##Contact
Github: {github}
Linkedin: {linkedin}

"""

print(readme)
# Out:
# Enter your name:   SONA K SOJAN
# Enter your course:   BCA
# Enter your collage:   JAIN UNIVERSITY KOCHI
# Enter your skills:   COMMUNICATION , PROBLEM SOLVING
# Enter your projects:   MY DIGITAL IDENTITY , STUDENT PROFILE MANAGER , RESUME GENERATOR
# Enter your linkedin:   https://www.linkedin.com/in/sona-k-sojan-022954422/
# Enter your github:    https://github.com/Sonaksojan2008
#
# #SONA K SOJAN
#
# ##About me
# I am SONA K SOJAN,a BCA,student at JAIN UNIVERSITY KOCHI
#
# ##Skills
# COMMUNICATION , PROBLEM SOLVING
#
# ##Projects
# MY DIGITAL IDENTITY , STUDENT PROFILE MANAGER , RESUME GENERATOR
#
# ##Contact
# Github: https://github.com/Sonaksojan2008
# Linkedin: https://www.linkedin.com/in/sona-k-sojan-022954422/
