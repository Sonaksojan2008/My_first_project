# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonaksojan2008/My_first_project/blob/main/Task_01_My_Digital_Identity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1 - My Digital Identity
name = "Sona k Sojan"
reg_no ="JSOFT26007"
department = "BCA"
semester = "1"
skills = "communication, problem solving "
hobbies = "singing"
dream_company = "meta"
github = "https://github.com/Sonaksojan2008"
linkedin = "https://www.linkedin.com/in/sona-k-sojan-022954422/"
career_goal = "To become software engineer"

print("=" * 40)
print("        MY DIGITAL IDENTITY")
print("=" * 40)
print(f"Name          :{name}")
print(f"Reg_no        :{reg_no}")
print(f"Department    :{department}")
print(f"Semester      :{semester}")
print(f"Skills        :{skills}")
print(f"Hobbies       :{hobbies}")
print(f"Dream_company :{dream_company}")
print(f"Github        :{github}")
print(f"Linkedin      :{linkedin}")
print(f"Career_goal   :{career_goal}")
# Out:
# ...
#         MY DIGITAL IDENTITY
# ...
# Name          :Sona k Sojan
# Reg_no        :JSOFT26007
# Department    :BCA
# Semester      :1
# Skills        :communication, problem solving
# Hobbies       :singing
# Dream_company :meta
# Github        :https://github.com/Sonaksojan2008
# Linkedin      :https://www.linkedin.com/in/sona-k-sojan-022954422/
# Career_goal   :To become software engineer
