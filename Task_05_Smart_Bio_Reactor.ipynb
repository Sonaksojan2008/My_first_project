# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonaksojan2008/My_first_project/blob/main/Task_05_Smart_Bio_Reactor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "SONA K SOJAN"
course = "WORK INTEGRATED BCA"
skills = "COMMUNICATION,PROBLEM SOLVING,PYTHON"
career_goal = "FULL STACK AI DEVELOPER"
interest = "TECHNOLOGY,ARTIFICIAL INTELLIGENCE"

linkedin_bio = f"""
Hi, I am {name} , a {course} student passionate about {interest}.
I am developing my skills in {skills}.
My career goal is to become a {career_goal}.
"""

github_bio = f"""
Hi, I am {name}
{course} student
Skills: {skills}
Aspiring {career_goal}
Interest in {interest}
"""

website_bio = f"""
I am {name} currently pursuing a {course}.
My interest include {interest},and I am developing my
technical skills in {skills}. I aspire to build a career as a
{career_goal} and work on meaningful technology_driven projects
"""
print("------LINKEDIN BIO------")
print(linkedin_bio)
print("------GITHUB BIO------")
print(github_bio)
print("------WEBSITE BIO------")
print(website_bio)
print("------THANK YOU------")
# Out:
# ------LINKEDIN BIO------
#
# Hi, I am SONA K SOJAN , a WORK INTEGRATED BCA student passionate about TECHNOLOGY,ARTIFICIAL INTELLIGENCE.
# I am developing my skills in COMMUNICATION,PROBLEM SOLVING,PYTHON.
# My career goal is to become a FULL STACK AI DEVELOPER.
#
# ------GITHUB BIO------
#
# Hi, I am SONA K SOJAN
# WORK INTEGRATED BCA student
# Skills: COMMUNICATION,PROBLEM SOLVING,PYTHON
# Aspiring FULL STACK AI DEVELOPER
# Interest in TECHNOLOGY,ARTIFICIAL INTELLIGENCE
#
# ------WEBSITE BIO------
#
# I am SONA K SOJAN currently pursuing a WORK INTEGRATED BCA.
# My interest include TECHNOLOGY,ARTIFICIAL INTELLIGENCE,and I am developing my
# technical skills in COMMUNICATION,PROBLEM SOLVING,PYTHON. I aspire to build a career as a
# FULL STACK AI DEVELOPER and work on meaningful technology_driven projects
#
# ------THANK YOU------
